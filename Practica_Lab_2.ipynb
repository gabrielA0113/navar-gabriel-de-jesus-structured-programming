# %%
def multiply(a, b):
   return a * b
print(multiply(3,4))
# Out:
# 12

# %%
counter = 0
for i in range(4):
    counter = counter + 1
print(counter)
# Out:
# 4

# %%
age = int(input("Enter your age: "))
if age >= 18
    print("Adult")
# Out:
#   File "/tmp/ipykernel_1556/4160241736.py", line 2
#     if age >= 18
#                 ^
# SyntaxError: expected ':'

# %%
a = 3
b = 4

temp = a
a = b
b = temp
print(a)
print(b)
